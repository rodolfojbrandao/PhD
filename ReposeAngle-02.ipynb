# %%
# bibliotecas usadas
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# para gerar o grafico no browser
# %matplotlib inline
# !git clone http://github.com/rodolfojbrandao/PHD
# %cd PHD
DAT=pd.read_csv("ReposeAngleANN.csv")
# Out:
# fatal: destination path 'PHD' already exists and is not an empty directory.
# /content/PHD/PHD/PHD/PHD/PHD/PHD/PHD

# %%
# funcao normatiza dados
def Normatiza(x):
    strings=list(x)
    for i in strings:
        max_x=x[i].max()
        min_x=x[i].min()
        a=(max_x+min_x)/2
        b=(max_x-min_x)/2
        x[i]=(x[i]-a)/b
    return x

# %%
# funcao retorna os dados a forma original
def Original(x,x_old):
    strings=list(x)
    for i in strings:
        max_x=x_old[i].max()
        min_x=x_old[i].min()
        a=(max_x+min_x)/2
        b=(max_x-min_x)/2
        x[i]=x[i]*b+a
    return x

# %%
# separa os dados em normatizados e originais
DAT_OLD=[]
DAT_OLD=DAT.copy()
DAT=Normatiza(DAT)
# separa os dados em treino e teste
train=DAT.sample(frac=0.8,random_state=None) # poderia ser frac=0.5? sim ou nao?
test=DAT.drop(train.index)
# obtem as variaveis independentes (treino e teste)
Index01=[0,1,2,3,4,5,6,7]
x_train=train.iloc[:,]
x_test=test.iloc[:,Index01]
X_OLD=DAT_OLD.iloc[:,Index01]
# obtem as variaveis dependentes (treino e teste)
Index02=[8,9]
y_train=train.iloc[:,Index02]
y_test=test.iloc[:,Index02]
Y_OLD=DAT_OLD.iloc[:,Index02]

# %%
def rede(i,j):
    clf = MLPRegressor(solver='lbfgs',activation='tanh',alpha=1e-5,
                       hidden_layer_sizes=(i, j),random_state=1)
    return clf

# %%
N=10
M=10
test=[]
train=[]
train=Original(y_train,Y_OLD)
test=Original(y_test,Y_OLD)
col_names=list(y_train)
for i in range(1,N):
  #via de regra usa apenas (N), porem como payton começa do 0 mas não podemos ter zero neur
  for j in range(1,M):
    clf=rede(i,j)
    #clf=MLPRegressor(solver='lbfgs',activation='tanh',alpha=1e-5,hidden_layer_sizes=(i, j),random_state=1)
    clf.fit(x_train, y_train)
    y_calc_train=clf.predict(x_train)
    y_calc_test=clf.predict(x_test)
    y_calc_train=pd.DataFrame(y_calc_train)
    y_calc_test=pd.DataFrame(y_calc_test)
    y_calc_train.columns = col_names
    y_calc_test.columns = col_names
    y_calc_train=Original(y_calc_train,Y_OLD)
    y_calc_test=Original(y_calc_test,Y_OLD)
    resist_obs_train=[]
    resist_calc_train=[]
    resist_calc_train=y_calc_train['Superior'].copy()
    resist_obs_train=train['Superior'].copy()
    resist_obs_test=[]
    resist_calc_test=[]
    resist_calc_test=y_calc_test['Superior'].copy()
    resist_obs_test=test['Superior'].copy()
    mse=mean_squared_error(resist_obs_test,resist_calc_test)
    print(f'number of hidden layers are {i} and {j}')
    print("MSE teste=",mse)
    R2=r2_score(resist_obs_test,resist_calc_test)
    print("R^2 teste=",R2)
    print("==================================")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-70118b21caa8> in <module>()
#      13     clf.fit(x_train, y_train)
#      14     y_calc_train=clf.predict(x_train)
# ---> 15     y_calc_test=clf.predict(x_test)
#      16     y_calc_train=pd.DataFrame(y_calc_train)
#      17     y_calc_test=pd.DataFrame(y_calc_test)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py in predict(self, X)
#    1295         """
#    1296         check_is_fitted(self, "coefs_")
# -> 1297         y_pred = self._predict(X)
#    1298         if y_pred.shape[1] == 1:
#    1299             return y_pred.ravel()
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py in _predict(self, X)
#     676                                          layer_units[i + 1])))
#     677         # forward propagate
# --> 678         self._forward_pass(activations)
#     679         y_pred = activations[-1]
#     680
#
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/multilayer_perceptron.py in _forward_pass(self, activations)
#     103         for i in range(self.n_layers_ - 1):
#     104             activations[i + 1] = safe_sparse_dot(activations[i],
# --> 105                                                  self.coefs_[i])
#     106             activations[i + 1] += self.intercepts_[i]
#     107
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     138         return ret
#     139     else:
# --> 140         return np.dot(a, b)
#     141
#     142
#
# ValueError: shapes (16,8) and (10,1) not aligned: 8 (dim 1) != 10 (dim 0)
